# %% [markdown]
# # Pull california housing data

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

raw = fetch_california_housing()
df = pd.DataFrame(raw.data, columns=raw.feature_names)
df['median_house_value'] = raw.target

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  median_house_value
# 0    -122.23               4.526
# 1    -122.22               3.585
# 2    -122.24               3.521
# 3    -122.25               3.413
# 4    -122.25               3.422

# %%
df.shape
# Out:
# (20640, 9)

# %% [markdown]
# # Add county information

# %%
# map coordinates to zip code/county to give us categorical variables to work with
import json
import os
import time

import geopy
from tqdm import tqdm_notebook


import json


if not os.path.exists('geo.json'):
    try:
        results
    except NameError:
        results = {}
    geolocator = geopy.geocoders.Nominatim(country_bias='USA', user_agent='housing')
    coordinates = list(df[['Latitude', 'Longitude']].itertuples(name='Coordinates'))
    for c in tqdm_notebook(coordinates):
        try:
            if not c.Index in results:
                results[c.Index] = geolocator.reverse((c.Latitude, c.Longitude))
                time.sleep(1)
        except Exception:
            pass
    with open('geo.json', 'w') as f:
        results = {k: v.raw for k, v in results.items()}
        json.dump(results, f)
else:
    results = json.load(open('geo.json'))

# %%
results
# Out:
# {'0': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Contra Costa County',
#    'house_number': '2981',
#    'postcode': '94611',
#    'road': 'Grizzly Peak Boulevard',
#    'state': 'California'},
#   'boundingbox': ['37.880400840239',
#    '37.880600840239',
#    '-122.22990352754',
#    '-122.22970352754'],
#   'display_name': '2981, Grizzly Peak Boulevard, Oakland, Contra Costa County, California, 94611, USA',
#   'lat': '37.8805008402394',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.229803527544',
#   'osm_id': '5149902',
#   'osm_type': 'way',
#   'place_id': '204090201'},
#  '1': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '2004',
#    'postcode': '94611',
#    'road': 'Tunnel Road',
#    'state': 'California'},
#   'boundingbox': ['37.85931709178',
#    '37.85951709178',
#    '-122.21958253407',
#    '-122.21938253407'],
#   'display_name': '2004, Tunnel Road, Oakland, Alameda County, California, 94611, USA',
#   'lat': '37.8594170917804',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.219482534068',
#   'osm_id': '24501520',
#   'osm_type': 'way',
#   'place_id': '204080388'},
#  '2': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Upper Rockridge',
#    'postcode': '94618',
#    'road': 'Grove Shafter Freeway',
#    'state': 'California'},
#   'boundingbox': ['37.8500633', '37.8501162', '-122.2401036', '-122.2396155'],
#   'display_name': 'Grove Shafter Freeway, Upper Rockridge, Oakland, Alameda County, California, 94618, USA',
#   'lat': '37.8500752088472',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.240009520107',
#   'osm_id': '25006990',
#   'osm_type': 'way',
#   'place_id': '81061927'},
#  '3': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '6369',
#    'neighbourhood': 'Rockridge',
#    'postcode': '94618',
#    'road': 'Florio Street',
#    'state': 'California'},
#   'boundingbox': ['37.849877272727',
#    '37.850077272727',
#    '-122.25009427273',
#    '-122.24989427273'],
#   'display_name': '6369, Florio Street, Rockridge, Oakland, Alameda County, California, 94618, USA',
#   'lat': '37.8499772727273',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.249994272727',
#   'osm_id': '22960962',
#   'osm_type': 'way',
#   'place_id': '204108225'},
#  '4': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '6369',
#    'neighbourhood': 'Rockridge',
#    'postcode': '94618',
#    'road': 'Florio Street',
#    'state': 'California'},
#   'boundingbox': ['37.849877272727',
#    '37.850077272727',
#    '-122.25009427273',
#    '-122.24989427273'],
#   'display_name': '6369, Florio Street, Rockridge, Oakland, Alameda County, California, 94618, USA',
#   'lat': '37.8499772727273',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.249994272727',
#   'osm_id': '22960962',
#   'osm_type': 'way',
#   'place_id': '204108225'},
#  '5': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '6369',
#    'neighbourhood': 'Rockridge',
#    'postcode': '94618',
#    'road': 'Florio Street',
#    'state': 'California'},
#   'boundingbox': ['37.849877272727',
#    '37.850077272727',
#    '-122.25009427273',
#    '-122.24989427273'],
#   'display_name': '6369, Florio Street, Rockridge, Oakland, Alameda County, California, 94618, USA',
#   'lat': '37.8499772727273',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.249994272727',
#   'osm_id': '22960962',
#   'osm_type': 'way',
#   'place_id': '204108225'},
#  '6': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '5398',
#    'neighbourhood': 'Rockridge',
#    'postcode': '94618',
#    'road': 'Bryant Avenue',
#    'state': 'California'},
#   'boundingbox': ['37.839794', '37.839994', '-122.250095', '-122.249895'],
#   'display_name': '5398, Bryant Avenue, Rockridge, Oakland, Alameda County, California, 94618, USA',
#   'lat': '37.839894',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.249995',
#   'osm_id': '6393564',
#   'osm_type': 'way',
#   'place_id': '204066902'},
#  '7': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '5398',
#    'neighbourhood': 'Rockridge',
#    'postcode': '94618',
#    'road': 'Bryant Avenue',
#    'state': 'California'},
#   'boundingbox': ['37.839794', '37.839994', '-122.250095', '-122.249895'],
#   'display_name': '5398, Bryant Avenue, Rockridge, Oakland, Alameda County, California, 94618, USA',
#   'lat': '37.839894',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.249995',
#   'osm_id': '6393564',
#   'osm_type': 'way',
#   'place_id': '204066902'},
#  '8': {'address': {'address29': 'Oakland Department of Motor Vehicles',
#    'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '5300',
#    'neighbourhood': 'Temescal',
#    'postcode': '94618',
#    'road': 'Claremont Avenue',
#    'state': 'California'},
#   'boundingbox': ['37.8393283', '37.8398117', '-122.2601029', '-122.2595494'],
#   'display_name': 'Oakland Department of Motor Vehicles, 5300, Claremont Avenue, Temescal, Oakland, Alameda County, California, 94618, USA',
#   'lat': '37.83959325',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.259804346494',
#   'osm_id': '37017762',
#   'osm_type': 'way',
#   'place_id': '84850539'},
#  '9': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '5398',
#    'neighbourhood': 'Rockridge',
#    'postcode': '94618',
#    'road': 'Bryant Avenue',
#    'state': 'California'},
#   'boundingbox': ['37.839794', '37.839994', '-122.250095', '-122.249895'],
#   'display_name': '5398, Bryant Avenue, Rockridge, Oakland, Alameda County, California, 94618, USA',
#   'lat': '37.839894',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.249995',
#   'osm_id': '6393564',
#   'osm_type': 'way',
#   'place_id': '204066902'},
#  '10': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Idora Park',
#    'pet': 'Pet Food Express',
#    'postcode': '94705',
#    'road': 'Alcatraz Avenue',
#    'state': 'California'},
#   'boundingbox': ['37.8498728', '37.8500728', '-122.2602068', '-122.2600068'],
#   'display_name': 'Pet Food Express, Alcatraz Avenue, Idora Park, Oakland, Alameda County, California, 94705, USA',
#   'lat': '37.8499728',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2601068',
#   'osm_id': '2336118595',
#   'osm_type': 'node',
#   'place_id': '23730325'},
#  '11': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Idora Park',
#    'pet': 'Pet Food Express',
#    'postcode': '94705',
#    'road': 'Alcatraz Avenue',
#    'state': 'California'},
#   'boundingbox': ['37.8498728', '37.8500728', '-122.2602068', '-122.2600068'],
#   'display_name': 'Pet Food Express, Alcatraz Avenue, Idora Park, Oakland, Alameda County, California, 94705, USA',
#   'lat': '37.8499728',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2601068',
#   'osm_id': '2336118595',
#   'osm_type': 'node',
#   'place_id': '23730325'},
#  '12': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Idora Park',
#    'pet': 'Pet Food Express',
#    'postcode': '94705',
#    'road': 'Alcatraz Avenue',
#    'state': 'California'},
#   'boundingbox': ['37.8498728', '37.8500728', '-122.2602068', '-122.2600068'],
#   'display_name': 'Pet Food Express, Alcatraz Avenue, Idora Park, Oakland, Alameda County, California, 94705, USA',
#   'lat': '37.8499728',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2601068',
#   'osm_id': '2336118595',
#   'osm_type': 'node',
#   'place_id': '23730325'},
#  '13': {'address': {'address29': 'Oakland Department of Motor Vehicles',
#    'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '5300',
#    'neighbourhood': 'Temescal',
#    'postcode': '94618',
#    'road': 'Claremont Avenue',
#    'state': 'California'},
#   'boundingbox': ['37.8393283', '37.8398117', '-122.2601029', '-122.2595494'],
#   'display_name': 'Oakland Department of Motor Vehicles, 5300, Claremont Avenue, Temescal, Oakland, Alameda County, California, 94618, USA',
#   'lat': '37.83959325',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.259804346494',
#   'osm_id': '37017762',
#   'osm_type': 'way',
#   'place_id': '84850539'},
#  '14': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Idora Park',
#    'pet': 'Pet Food Express',
#    'postcode': '94705',
#    'road': 'Alcatraz Avenue',
#    'state': 'California'},
#   'boundingbox': ['37.8498728', '37.8500728', '-122.2602068', '-122.2600068'],
#   'display_name': 'Pet Food Express, Alcatraz Avenue, Idora Park, Oakland, Alameda County, California, 94705, USA',
#   'lat': '37.8499728',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2601068',
#   'osm_id': '2336118595',
#   'osm_type': 'node',
#   'place_id': '23730325'},
#  '15': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Idora Park',
#    'pet': 'Pet Food Express',
#    'postcode': '94705',
#    'road': 'Alcatraz Avenue',
#    'state': 'California'},
#   'boundingbox': ['37.8498728', '37.8500728', '-122.2602068', '-122.2600068'],
#   'display_name': 'Pet Food Express, Alcatraz Avenue, Idora Park, Oakland, Alameda County, California, 94705, USA',
#   'lat': '37.8499728',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2601068',
#   'osm_id': '2336118595',
#   'osm_type': 'node',
#   'place_id': '23730325'},
#  '16': {'address': {'city': 'Berkeley',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '1917',
#    'neighbourhood': 'Lorin',
#    'postcode': '94703',
#    'road': 'Harmon Street',
#    'state': 'California'},
#   'boundingbox': ['37.849768908329',
#    '37.849968908329',
#    '-122.27006962632',
#    '-122.26986962631'],
#   'display_name': '1917, Harmon Street, Lorin, Berkeley, Alameda County, California, 94703, USA',
#   'lat': '37.8498689083288',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.269969626315',
#   'osm_id': '164659467',
#   'osm_type': 'way',
#   'place_id': '204068520'},
#  '17': {'address': {'city': 'Berkeley',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '1917',
#    'neighbourhood': 'Lorin',
#    'postcode': '94703',
#    'road': 'Harmon Street',
#    'state': 'California'},
#   'boundingbox': ['37.849768908329',
#    '37.849968908329',
#    '-122.27006962632',
#    '-122.26986962631'],
#   'display_name': '1917, Harmon Street, Lorin, Berkeley, Alameda County, California, 94703, USA',
#   'lat': '37.8498689083288',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.269969626315',
#   'osm_id': '164659467',
#   'osm_type': 'way',
#   'place_id': '204068520'},
#  '18': {'address': {'address29': 'Oakland Department of Motor Vehicles',
#    'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '5300',
#    'neighbourhood': 'Temescal',
#    'postcode': '94618',
#    'road': 'Claremont Avenue',
#    'state': 'California'},
#   'boundingbox': ['37.8393283', '37.8398117', '-122.2601029', '-122.2595494'],
#   'display_name': 'Oakland Department of Motor Vehicles, 5300, Claremont Avenue, Temescal, Oakland, Alameda County, California, 94618, USA',
#   'lat': '37.83959325',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.259804346494',
#   'osm_id': '37017762',
#   'osm_type': 'way',
#   'place_id': '84850539'},
#  '19': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'fuel': 'Fuel 24:7',
#    'postcode': '94609',
#    'road': 'Martin Luther King Junior Way',
#    'state': 'California'},
#   'boundingbox': ['37.8399252', '37.8401252', '-122.2702261', '-122.2700261'],
#   'display_name': 'Fuel 24:7, Martin Luther King Junior Way, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8400252',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2701261',
#   'osm_id': '212469149',
#   'osm_type': 'node',
#   'place_id': '550594'},
#  '20': {'address': {'city': 'Berkeley',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '1917',
#    'neighbourhood': 'Lorin',
#    'postcode': '94703',
#    'road': 'Harmon Street',
#    'state': 'California'},
#   'boundingbox': ['37.849768908329',
#    '37.849968908329',
#    '-122.27006962632',
#    '-122.26986962631'],
#   'display_name': '1917, Harmon Street, Lorin, Berkeley, Alameda County, California, 94703, USA',
#   'lat': '37.8498689083288',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.269969626315',
#   'osm_id': '164659467',
#   'osm_type': 'way',
#   'place_id': '204068520'},
#  '21': {'address': {'city': 'Berkeley',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '1917',
#    'neighbourhood': 'Lorin',
#    'postcode': '94703',
#    'road': 'Harmon Street',
#    'state': 'California'},
#   'boundingbox': ['37.849768908329',
#    '37.849968908329',
#    '-122.27006962632',
#    '-122.26986962631'],
#   'display_name': '1917, Harmon Street, Lorin, Berkeley, Alameda County, California, 94703, USA',
#   'lat': '37.8498689083288',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.269969626315',
#   'osm_id': '164659467',
#   'osm_type': 'way',
#   'place_id': '204068520'},
#  '22': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'fuel': 'Fuel 24:7',
#    'postcode': '94609',
#    'road': 'Martin Luther King Junior Way',
#    'state': 'California'},
#   'boundingbox': ['37.8399252', '37.8401252', '-122.2702261', '-122.2700261'],
#   'display_name': 'Fuel 24:7, Martin Luther King Junior Way, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8400252',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2701261',
#   'osm_id': '212469149',
#   'osm_type': 'node',
#   'place_id': '550594'},
#  '23': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'fuel': 'Fuel 24:7',
#    'postcode': '94609',
#    'road': 'Martin Luther King Junior Way',
#    'state': 'California'},
#   'boundingbox': ['37.8399252', '37.8401252', '-122.2702261', '-122.2700261'],
#   'display_name': 'Fuel 24:7, Martin Luther King Junior Way, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8400252',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2701261',
#   'osm_id': '212469149',
#   'osm_type': 'node',
#   'place_id': '550594'},
#  '24': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'fuel': 'Fuel 24:7',
#    'postcode': '94609',
#    'road': 'Martin Luther King Junior Way',
#    'state': 'California'},
#   'boundingbox': ['37.8399252', '37.8401252', '-122.2702261', '-122.2700261'],
#   'display_name': 'Fuel 24:7, Martin Luther King Junior Way, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8400252',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2701261',
#   'osm_id': '212469149',
#   'osm_type': 'node',
#   'place_id': '550594'},
#  '25': {'address': {'city': 'Berkeley',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '1408',
#    'neighbourhood': 'Harmon Tract',
#    'postcode': '94702',
#    'road': '66th Street',
#    'state': 'California'},
#   'boundingbox': ['37.849839787202',
#    '37.850039787202',
#    '-122.28009257066',
#    '-122.27989257066'],
#   'display_name': '1408, 66th Street, Harmon Tract, Berkeley, Alameda County, California, 94702, USA',
#   'lat': '37.8499397872024',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.279992570657',
#   'osm_id': '6397305',
#   'osm_type': 'way',
#   'place_id': '204078547'},
#  '26': {'address': {'city': 'Berkeley',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '1408',
#    'neighbourhood': 'Harmon Tract',
#    'postcode': '94702',
#    'road': '66th Street',
#    'state': 'California'},
#   'boundingbox': ['37.849839787202',
#    '37.850039787202',
#    '-122.28009257066',
#    '-122.27989257066'],
#   'display_name': '1408, 66th Street, Harmon Tract, Berkeley, Alameda County, California, 94702, USA',
#   'lat': '37.8499397872024',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.279992570657',
#   'osm_id': '6397305',
#   'osm_type': 'way',
#   'place_id': '204078547'},
#  '27': {'address': {'city': 'Berkeley',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '1408',
#    'neighbourhood': 'Harmon Tract',
#    'postcode': '94702',
#    'road': '66th Street',
#    'state': 'California'},
#   'boundingbox': ['37.849839787202',
#    '37.850039787202',
#    '-122.28009257066',
#    '-122.27989257066'],
#   'display_name': '1408, 66th Street, Harmon Tract, Berkeley, Alameda County, California, 94702, USA',
#   'lat': '37.8499397872024',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.279992570657',
#   'osm_id': '6397305',
#   'osm_type': 'way',
#   'place_id': '204078547'},
#  '28': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '1043',
#    'neighbourhood': 'Golden Gate',
#    'postcode': '94608',
#    'road': 'Aileen Street',
#    'state': 'California'},
#   'boundingbox': ['37.839900261016',
#    '37.840100261017',
#    '-122.28008627633',
#    '-122.27988627633'],
#   'display_name': '1043, Aileen Street, Golden Gate, Oakland, Alameda County, California, 94608, USA',
#   'lat': '37.8400002610165',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.279986276328',
#   'osm_id': '6336068',
#   'osm_type': 'way',
#   'place_id': '204090365'},
#  '29': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '1043',
#    'neighbourhood': 'Golden Gate',
#    'postcode': '94608',
#    'road': 'Aileen Street',
#    'state': 'California'},
#   'boundingbox': ['37.839900261016',
#    '37.840100261017',
#    '-122.28008627633',
#    '-122.27988627633'],
#   'display_name': '1043, Aileen Street, Golden Gate, Oakland, Alameda County, California, 94608, USA',
#   'lat': '37.8400002610165',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.279986276328',
#   'osm_id': '6336068',
#   'osm_type': 'way',
#   'place_id': '204090365'},
#  '30': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '1043',
#    'neighbourhood': 'Golden Gate',
#    'postcode': '94608',
#    'road': 'Aileen Street',
#    'state': 'California'},
#   'boundingbox': ['37.839900261016',
#    '37.840100261017',
#    '-122.28008627633',
#    '-122.27988627633'],
#   'display_name': '1043, Aileen Street, Golden Gate, Oakland, Alameda County, California, 94608, USA',
#   'lat': '37.8400002610165',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.279986276328',
#   'osm_id': '6336068',
#   'osm_type': 'way',
#   'place_id': '204090365'},
#  '31': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '1043',
#    'neighbourhood': 'Golden Gate',
#    'postcode': '94608',
#    'road': 'Aileen Street',
#    'state': 'California'},
#   'boundingbox': ['37.839900261016',
#    '37.840100261017',
#    '-122.28008627633',
#    '-122.27988627633'],
#   'display_name': '1043, Aileen Street, Golden Gate, Oakland, Alameda County, California, 94608, USA',
#   'lat': '37.8400002610165',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.279986276328',
#   'osm_id': '6336068',
#   'osm_type': 'way',
#   'place_id': '204090365'},
#  '32': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'fuel': 'Fuel 24:7',
#    'postcode': '94609',
#    'road': 'Martin Luther King Junior Way',
#    'state': 'California'},
#   'boundingbox': ['37.8399252', '37.8401252', '-122.2702261', '-122.2700261'],
#   'display_name': 'Fuel 24:7, Martin Luther King Junior Way, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8400252',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2701261',
#   'osm_id': '212469149',
#   'osm_type': 'node',
#   'place_id': '550594'},
#  '33': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '743',
#    'neighbourhood': 'Longfellow',
#    'postcode': '94609',
#    'road': '40th Street',
#    'state': 'California'},
#   'boundingbox': ['37.829899610819',
#    '37.830099610819',
#    '-122.27009801597',
#    '-122.26989801597'],
#   'display_name': '743, 40th Street, Longfellow, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8299996108186',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.269998015969',
#   'osm_id': '416170403',
#   'osm_type': 'way',
#   'place_id': '204122325'},
#  '34': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '743',
#    'neighbourhood': 'Longfellow',
#    'postcode': '94609',
#    'road': '40th Street',
#    'state': 'California'},
#   'boundingbox': ['37.829899610819',
#    '37.830099610819',
#    '-122.27009801597',
#    '-122.26989801597'],
#   'display_name': '743, 40th Street, Longfellow, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8299996108186',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.269998015969',
#   'osm_id': '416170403',
#   'osm_type': 'way',
#   'place_id': '204122325'},
#  '35': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '743',
#    'neighbourhood': 'Longfellow',
#    'postcode': '94609',
#    'road': '40th Street',
#    'state': 'California'},
#   'boundingbox': ['37.829899610819',
#    '37.830099610819',
#    '-122.27009801597',
#    '-122.26989801597'],
#   'display_name': '743, 40th Street, Longfellow, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8299996108186',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.269998015969',
#   'osm_id': '416170403',
#   'osm_type': 'way',
#   'place_id': '204122325'},
#  '36': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '743',
#    'neighbourhood': 'Longfellow',
#    'postcode': '94609',
#    'road': '40th Street',
#    'state': 'California'},
#   'boundingbox': ['37.829899610819',
#    '37.830099610819',
#    '-122.27009801597',
#    '-122.26989801597'],
#   'display_name': '743, 40th Street, Longfellow, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8299996108186',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.269998015969',
#   'osm_id': '416170403',
#   'osm_type': 'way',
#   'place_id': '204122325'},
#  '37': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '3889',
#    'postcode': '94608',
#    'road': 'San Pablo Avenue',
#    'state': 'California',
#    'supermarket': 'Pak N Save',
#    'town': 'Emeryville'},
#   'boundingbox': ['37.8289146', '37.8297865', '-122.2805491', '-122.2795505'],
#   'display_name': 'Pak N Save, 3889, San Pablo Avenue, Emeryville, Alameda County, California, 94608, USA',
#   'lat': '37.8292479',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.280051804471',
#   'osm_id': '43824884',
#   'osm_type': 'way',
#   'place_id': '86932057'},
#  '38': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '4138',
#    'neighbourhood': 'Mosswood',
#    'postcode': '94609',
#    'road': 'Webster Street',
#    'state': 'California'},
#   'boundingbox': ['37.829988446746',
#    '37.830188446746',
#    '-122.26044102242',
#    '-122.26024102242'],
#   'display_name': '4138, Webster Street, Mosswood, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8300884467464',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.260341022422',
#   'osm_id': '25841021',
#   'osm_type': 'way',
#   'place_id': '204112100'},
#  '39': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '4138',
#    'neighbourhood': 'Mosswood',
#    'postcode': '94609',
#    'road': 'Webster Street',
#    'state': 'California'},
#   'boundingbox': ['37.829988446746',
#    '37.830188446746',
#    '-122.26044102242',
#    '-122.26024102242'],
#   'display_name': '4138, Webster Street, Mosswood, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8300884467464',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.260341022422',
#   'osm_id': '25841021',
#   'osm_type': 'way',
#   'place_id': '204112100'},
#  '40': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '4138',
#    'neighbourhood': 'Mosswood',
#    'postcode': '94609',
#    'road': 'Webster Street',
#    'state': 'California'},
#   'boundingbox': ['37.829988446746',
#    '37.830188446746',
#    '-122.26044102242',
#    '-122.26024102242'],
#   'display_name': '4138, Webster Street, Mosswood, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8300884467464',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.260341022422',
#   'osm_id': '25841021',
#   'osm_type': 'way',
#   'place_id': '204112100'},
#  '41': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '4138',
#    'neighbourhood': 'Mosswood',
#    'postcode': '94609',
#    'road': 'Webster Street',
#    'state': 'California'},
#   'boundingbox': ['37.829988446746',
#    '37.830188446746',
#    '-122.26044102242',
#    '-122.26024102242'],
#   'display_name': '4138, Webster Street, Mosswood, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8300884467464',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.260341022422',
#   'osm_id': '25841021',
#   'osm_type': 'way',
#   'place_id': '204112100'},
#  '42': {'address': {'address29': 'Oakland Department of Motor Vehicles',
#    'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '5300',
#    'neighbourhood': 'Temescal',
#    'postcode': '94618',
#    'road': 'Claremont Avenue',
#    'state': 'California'},
#   'boundingbox': ['37.8393283', '37.8398117', '-122.2601029', '-122.2595494'],
#   'display_name': 'Oakland Department of Motor Vehicles, 5300, Claremont Avenue, Temescal, Oakland, Alameda County, California, 94618, USA',
#   'lat': '37.83959325',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.259804346494',
#   'osm_id': '37017762',
#   'osm_type': 'way',
#   'place_id': '84850539'},
#  '43': {'address': {'address29': 'Oakland Department of Motor Vehicles',
#    'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '5300',
#    'neighbourhood': 'Temescal',
#    'postcode': '94618',
#    'road': 'Claremont Avenue',
#    'state': 'California'},
#   'boundingbox': ['37.8393283', '37.8398117', '-122.2601029', '-122.2595494'],
#   'display_name': 'Oakland Department of Motor Vehicles, 5300, Claremont Avenue, Temescal, Oakland, Alameda County, California, 94618, USA',
#   'lat': '37.83959325',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.259804346494',
#   'osm_id': '37017762',
#   'osm_type': 'way',
#   'place_id': '84850539'},
#  '44': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '4138',
#    'neighbourhood': 'Mosswood',
#    'postcode': '94609',
#    'road': 'Webster Street',
#    'state': 'California'},
#   'boundingbox': ['37.829988446746',
#    '37.830188446746',
#    '-122.26044102242',
#    '-122.26024102242'],
#   'display_name': '4138, Webster Street, Mosswood, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8300884467464',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.260341022422',
#   'osm_id': '25841021',
#   'osm_type': 'way',
#   'place_id': '204112100'},
#  '45': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '4138',
#    'neighbourhood': 'Mosswood',
#    'postcode': '94609',
#    'road': 'Webster Street',
#    'state': 'California'},
#   'boundingbox': ['37.829988446746',
#    '37.830188446746',
#    '-122.26044102242',
#    '-122.26024102242'],
#   'display_name': '4138, Webster Street, Mosswood, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8300884467464',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.260341022422',
#   'osm_id': '25841021',
#   'osm_type': 'way',
#   'place_id': '204112100'},
#  '46': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '4138',
#    'neighbourhood': 'Mosswood',
#    'postcode': '94609',
#    'road': 'Webster Street',
#    'state': 'California'},
#   'boundingbox': ['37.829988446746',
#    '37.830188446746',
#    '-122.26044102242',
#    '-122.26024102242'],
#   'display_name': '4138, Webster Street, Mosswood, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8300884467464',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.260341022422',
#   'osm_id': '25841021',
#   'osm_type': 'way',
#   'place_id': '204112100'},
#  '47': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Hoover-Foster',
#    'postcode': '94609',
#    'road': 'Grove Shafter Freeway',
#    'state': 'California'},
#   'boundingbox': ['37.8196473', '37.8262013', '-122.2698263', '-122.2680443'],
#   'display_name': 'Grove Shafter Freeway, Hoover-Foster, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8199305036133',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.269748151363',
#   'osm_id': '28183673',
#   'osm_type': 'way',
#   'place_id': '82262499'},
#  '48': {'address': {'car_repair': 'Independent Factory Automotive',
#    'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Oak Glen Park',
#    'postcode': '94612',
#    'road': 'Brook Street',
#    'state': 'California'},
#   'boundingbox': ['37.8202769', '37.820617', '-122.2607169', '-122.2601845'],
#   'display_name': 'Independent Factory Automotive, Brook Street, Oak Glen Park, Oakland, Alameda County, California, 94612, USA',
#   'lat': '37.820438',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.260447196708',
#   'osm_id': '106994771',
#   'osm_type': 'way',
#   'place_id': '99245235'},
#  '49': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Hoover-Foster',
#    'postcode': '94609',
#    'road': 'Grove Shafter Freeway',
#    'state': 'California'},
#   'boundingbox': ['37.8196473', '37.8262013', '-122.2698263', '-122.2680443'],
#   'display_name': 'Grove Shafter Freeway, Hoover-Foster, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8199305036133',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.269748151363',
#   'osm_id': '28183673',
#   'osm_type': 'way',
#   'place_id': '82262499'},
#  '50': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Hoover-Foster',
#    'postcode': '94609',
#    'road': 'Grove Shafter Freeway',
#    'state': 'California'},
#   'boundingbox': ['37.8196473', '37.8262013', '-122.2698263', '-122.2680443'],
#   'display_name': 'Grove Shafter Freeway, Hoover-Foster, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8199305036133',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.269748151363',
#   'osm_id': '28183673',
#   'osm_type': 'way',
#   'place_id': '82262499'},
#  '51': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Hoover-Foster',
#    'postcode': '94609',
#    'road': 'Grove Shafter Freeway',
#    'state': 'California'},
#   'boundingbox': ['37.8196473', '37.8262013', '-122.2698263', '-122.2680443'],
#   'display_name': 'Grove Shafter Freeway, Hoover-Foster, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8199305036133',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.269748151363',
#   'osm_id': '28183673',
#   'osm_type': 'way',
#   'place_id': '82262499'},
#  '52': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Hoover-Foster',
#    'postcode': '94609',
#    'road': 'Grove Shafter Freeway',
#    'state': 'California'},
#   'boundingbox': ['37.8196473', '37.8262013', '-122.2698263', '-122.2680443'],
#   'display_name': 'Grove Shafter Freeway, Hoover-Foster, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8199305036133',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.269748151363',
#   'osm_id': '28183673',
#   'osm_type': 'way',
#   'place_id': '82262499'},
#  '53': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Hoover-Foster',
#    'postcode': '94609',
#    'road': 'Grove Shafter Freeway',
#    'state': 'California'},
#   'boundingbox': ['37.8196473', '37.8262013', '-122.2698263', '-122.2680443'],
#   'display_name': 'Grove Shafter Freeway, Hoover-Foster, Oakland, Alameda County, California, 94609, USA',
#   'lat': '37.8199305036133',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.269748151363',
#   'osm_id': '28183673',
#   'osm_type': 'way',
#   'place_id': '82262499'},
#  '54': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '2718',
#    'neighbourhood': 'Hoover-Foster',
#    'postcode': '94608',
#    'road': 'Linden Street',
#    'state': 'California'},
#   'boundingbox': ['37.819883088515',
#    '37.820083088516',
#    '-122.28006566328',
#    '-122.27986566328'],
#   'display_name': '2718, Linden Street, Hoover-Foster, Oakland, Alameda County, California, 94608, USA',
#   'lat': '37.8199830885155',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.279965663281',
#   'osm_id': '6331298',
#   'osm_type': 'way',
#   'place_id': '204106574'},
#  '55': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '2718',
#    'neighbourhood': 'Hoover-Foster',
#    'postcode': '94608',
#    'road': 'Linden Street',
#    'state': 'California'},
#   'boundingbox': ['37.819883088515',
#    '37.820083088516',
#    '-122.28006566328',
#    '-122.27986566328'],
#   'display_name': '2718, Linden Street, Hoover-Foster, Oakland, Alameda County, California, 94608, USA',
#   'lat': '37.8199830885155',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.279965663281',
#   'osm_id': '6331298',
#   'osm_type': 'way',
#   'place_id': '204106574'},
#  '56': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '2718',
#    'neighbourhood': 'Hoover-Foster',
#    'postcode': '94608',
#    'road': 'Linden Street',
#    'state': 'California'},
#   'boundingbox': ['37.819883088515',
#    '37.820083088516',
#    '-122.28006566328',
#    '-122.27986566328'],
#   'display_name': '2718, Linden Street, Hoover-Foster, Oakland, Alameda County, California, 94608, USA',
#   'lat': '37.8199830885155',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.279965663281',
#   'osm_id': '6331298',
#   'osm_type': 'way',
#   'place_id': '204106574'},
#  '57': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '2718',
#    'neighbourhood': 'Hoover-Foster',
#    'postcode': '94608',
#    'road': 'Linden Street',
#    'state': 'California'},
#   'boundingbox': ['37.819883088515',
#    '37.820083088516',
#    '-122.28006566328',
#    '-122.27986566328'],
#   'display_name': '2718, Linden Street, Hoover-Foster, Oakland, Alameda County, California, 94608, USA',
#   'lat': '37.8199830885155',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.279965663281',
#   'osm_id': '6331298',
#   'osm_type': 'way',
#   'place_id': '204106574'},
#  '58': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '2718',
#    'neighbourhood': 'Hoover-Foster',
#    'postcode': '94608',
#    'road': 'Linden Street',
#    'state': 'California'},
#   'boundingbox': ['37.819883088515',
#    '37.820083088516',
#    '-122.28006566328',
#    '-122.27986566328'],
#   'display_name': '2718, Linden Street, Hoover-Foster, Oakland, Alameda County, California, 94608, USA',
#   'lat': '37.8199830885155',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.279965663281',
#   'osm_id': '6331298',
#   'osm_type': 'way',
#   'place_id': '204106574'},
#  '59': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '2500',
#    'neighbourhood': 'West Oakland',
#    'postcode': '94607',
#    'road': 'Willow Street',
#    'state': 'California'},
#   'boundingbox': ['37.820179575758',
#    '37.820379575758',
#    '-122.29045309091',
#    '-122.29025309091'],
#   'display_name': '2500, Willow Street, West Oakland, Oakland, Alameda County, California, 94607, USA',
#   'lat': '37.8202795757576',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.290353090909',
#   'osm_id': '11185522',
#   'osm_type': 'way',
#   'place_id': '204142833'},
#  '60': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'postcode': '94608',
#    'road': 'Halleck Street',
#    'shop': "TNT's Screen Printing",
#    'state': 'California',
#    'town': 'Emeryville'},
#   'boundingbox': ['37.8293641', '37.8295641', '-122.2902449', '-122.2900449'],
#   'display_name': "TNT's Screen Printing, Halleck Street, Emeryville, Alameda County, California, 94608, USA",
#   'lat': '37.8294641',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2901449',
#   'osm_id': '5286837099',
#   'osm_type': 'node',
#   'place_id': '63360912'},
#  '61': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '2500',
#    'neighbourhood': 'West Oakland',
#    'postcode': '94607',
#    'road': 'Willow Street',
#    'state': 'California'},
#   'boundingbox': ['37.820179575758',
#    '37.820379575758',
#    '-122.29045309091',
#    '-122.29025309091'],
#   'display_name': '2500, Willow Street, West Oakland, Oakland, Alameda County, California, 94607, USA',
#   'lat': '37.8202795757576',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.290353090909',
#   'osm_id': '11185522',
#   'osm_type': 'way',
#   'place_id': '204142833'},
#  '62': {'address': {'bus_stop': '14th St:Poplar St',
#    'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'West Oakland',
#    'postcode': 'CA 94607',
#    'road': '14th Street',
#    'state': 'California'},
#   'boundingbox': ['37.8099819', '37.8101819', '-122.2891561', '-122.2889561'],
#   'display_name': '14th St:Poplar St, 14th Street, West Oakland, Oakland, Alameda County, California, CA 94607, USA',
#   'lat': '37.8100819',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2890561',
#   'osm_id': '5845170196',
#   'osm_type': 'node',
#   'place_id': '236650975'},
#  '63': {'address': {'artwork': '10th Street Woman Mural',
#    'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Lower Bottoms',
#    'postcode': 'CA 94607',
#    'road': '10th Street',
#    'state': 'California'},
#   'boundingbox': ['37.8097019', '37.8099019', '-122.2993972', '-122.2991972'],
#   'display_name': '10th Street Woman Mural, 10th Street, Lower Bottoms, Oakland, Alameda County, California, CA 94607, USA',
#   'lat': '37.8098019',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2992972',
#   'osm_id': '3982993366',
#   'osm_type': 'node',
#   'place_id': '50933414'},
#  '64': {'address': {'artwork': '10th Street Woman Mural',
#    'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Lower Bottoms',
#    'postcode': 'CA 94607',
#    'road': '10th Street',
#    'state': 'California'},
#   'boundingbox': ['37.8097019', '37.8099019', '-122.2993972', '-122.2991972'],
#   'display_name': '10th Street Woman Mural, 10th Street, Lower Bottoms, Oakland, Alameda County, California, CA 94607, USA',
#   'lat': '37.8098019',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2992972',
#   'osm_id': '3982993366',
#   'osm_type': 'node',
#   'place_id': '50933414'},
#  '65': {'address': {'artwork': '10th Street Woman Mural',
#    'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Lower Bottoms',
#    'postcode': 'CA 94607',
#    'road': '10th Street',
#    'state': 'California'},
#   'boundingbox': ['37.8097019', '37.8099019', '-122.2993972', '-122.2991972'],
#   'display_name': '10th Street Woman Mural, 10th Street, Lower Bottoms, Oakland, Alameda County, California, CA 94607, USA',
#   'lat': '37.8098019',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2992972',
#   'osm_id': '3982993366',
#   'osm_type': 'node',
#   'place_id': '50933414'},
#  '66': {'address': {'artwork': '10th Street Woman Mural',
#    'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Lower Bottoms',
#    'postcode': 'CA 94607',
#    'road': '10th Street',
#    'state': 'California'},
#   'boundingbox': ['37.8097019', '37.8099019', '-122.2993972', '-122.2991972'],
#   'display_name': '10th Street Woman Mural, 10th Street, Lower Bottoms, Oakland, Alameda County, California, CA 94607, USA',
#   'lat': '37.8098019',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2992972',
#   'osm_id': '3982993366',
#   'osm_type': 'node',
#   'place_id': '50933414'},
#  '67': {'address': {'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '1300',
#    'neighbourhood': 'South Prescott',
#    'postcode': '94607',
#    'road': 'Middle Harbor Road',
#    'state': 'California'},
#   'boundingbox': ['37.799516', '37.799716', '-122.290284', '-122.290084'],
#   'display_name': '1300, Middle Harbor Road, South Prescott, Oakland, Alameda County, California, 94607, USA',
#   'lat': '37.799616',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.290184',
#   'osm_id': '35353542',
#   'osm_type': 'way',
#   'place_id': '204113676'},
#  '68': {'address': {'artwork': '10th Street Woman Mural',
#    'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Lower Bottoms',
#    'postcode': 'CA 94607',
#    'road': '10th Street',
#    'state': 'California'},
#   'boundingbox': ['37.8097019', '37.8099019', '-122.2993972', '-122.2991972'],
#   'display_name': '10th Street Woman Mural, 10th Street, Lower Bottoms, Oakland, Alameda County, California, CA 94607, USA',
#   'lat': '37.8098019',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2992972',
#   'osm_id': '3982993366',
#   'osm_type': 'node',
#   'place_id': '50933414'},
#  '69': {'address': {'bus_stop': '14th St:Poplar St',
#    'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'West Oakland',
#    'postcode': 'CA 94607',
#    'road': '14th Street',
#    'state': 'California'},
#   'boundingbox': ['37.8099819', '37.8101819', '-122.2891561', '-122.2889561'],
#   'display_name': '14th St:Poplar St, 14th Street, West Oakland, Oakland, Alameda County, California, CA 94607, USA',
#   'lat': '37.8100819',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2890561',
#   'osm_id': '5845170196',
#   'osm_type': 'node',
#   'place_id': '236650975'},
#  '70': {'address': {'bus_stop': '14th St:Poplar St',
#    'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'West Oakland',
#    'postcode': 'CA 94607',
#    'road': '14th Street',
#    'state': 'California'},
#   'boundingbox': ['37.8099819', '37.8101819', '-122.2891561', '-122.2889561'],
#   'display_name': '14th St:Poplar St, 14th Street, West Oakland, Oakland, Alameda County, California, CA 94607, USA',
#   'lat': '37.8100819',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-122.2890561',
#   'osm_id': '5845170196',
#   'osm_type': 'node',
#   'place_id': '236650975'},
#  '71': {'address': {'bus_stop': '14th St:Poplar St',
#    'city': 'Oakland',
#    'country': 'USA',
#    'country_code': 'us',
# ...
#    'postcode': '94566',
#    'road': 'Pine Hill Lane',
#    'state': 'California',
#    'town': 'Pleasanton'},
#   'boundingbox': ['37.659957948387',
#    '37.660157948387',
#    '-121.87012087096',
#    '-121.86992087096'],
#   'display_name': '485, Pine Hill Lane, Pleasanton, Alameda County, California, 94566, USA',
#   'lat': '37.6600579483868',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.870020870959',
#   'osm_id': '6368111',
#   'osm_type': 'way',
#   'place_id': '204100011'},
#  '975': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '485',
#    'postcode': '94566',
#    'road': 'Pine Hill Lane',
#    'state': 'California',
#    'town': 'Pleasanton'},
#   'boundingbox': ['37.659957948387',
#    '37.660157948387',
#    '-121.87012087096',
#    '-121.86992087096'],
#   'display_name': '485, Pine Hill Lane, Pleasanton, Alameda County, California, 94566, USA',
#   'lat': '37.6600579483868',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.870020870959',
#   'osm_id': '6368111',
#   'osm_type': 'way',
#   'place_id': '204100011'},
#  '976': {'address': {'attraction': 'Alameda County Fairgrounds',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'postcode': '94566',
#    'road': 'Road 10',
#    'state': 'California',
#    'town': 'Pleasanton'},
#   'boundingbox': ['37.6583147', '37.6656997', '-121.8971866', '-121.8800554'],
#   'display_name': 'Alameda County Fairgrounds, Road 10, Pleasanton, Alameda County, California, 94566, USA',
#   'lat': '37.66199115',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.888554744766',
#   'osm_id': '317356',
#   'osm_type': 'relation',
#   'place_id': '197756214'},
#  '977': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '454',
#    'postcode': '94566',
#    'road': 'Matthew Court',
#    'state': 'California',
#    'town': 'Pleasanton'},
#   'boundingbox': ['37.639673019677',
#    '37.639873019677',
#    '-121.88010938574',
#    '-121.87990938574'],
#   'display_name': '454, Matthew Court, Pleasanton, Alameda County, California, 94566, USA',
#   'lat': '37.6397730196771',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.880009385736',
#   'osm_id': '6390329',
#   'osm_type': 'way',
#   'place_id': '204095513'},
#  '978': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'hamlet': 'Scotts Corner',
#    'postcode': '94586',
#    'road': 'Calaveras Road',
#    'state': 'California'},
#   'boundingbox': ['37.5603194', '37.5701024', '-121.8646538', '-121.863318'],
#   'display_name': 'Calaveras Road, Scotts Corner, Alameda County, California, 94586, USA',
#   'lat': '37.5680414',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.8646538',
#   'osm_id': '508151784',
#   'osm_type': 'way',
#   'place_id': '183440766'},
#  '979': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '4084',
#    'postcode': '94566',
#    'road': 'Graham Street',
#    'state': 'California',
#    'town': 'Pleasanton'},
#   'boundingbox': ['37.670111537417',
#    '37.670311537417',
#    '-121.87015337032',
#    '-121.86995337032'],
#   'display_name': '4084, Graham Street, Pleasanton, Alameda County, California, 94566, USA',
#   'lat': '37.6702115374172',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.870053370321',
#   'osm_id': '6347291',
#   'osm_type': 'way',
#   'place_id': '204063774'},
#  '980': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '4084',
#    'postcode': '94566',
#    'road': 'Graham Street',
#    'state': 'California',
#    'town': 'Pleasanton'},
#   'boundingbox': ['37.670111537417',
#    '37.670311537417',
#    '-121.87015337032',
#    '-121.86995337032'],
#   'display_name': '4084, Graham Street, Pleasanton, Alameda County, California, 94566, USA',
#   'lat': '37.6702115374172',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.870053370321',
#   'osm_id': '6347291',
#   'osm_type': 'way',
#   'place_id': '204063774'},
#  '981': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Shadow Cliffs',
#    'postcode': '94568',
#    'state': 'California',
#    'town': 'Pleasanton'},
#   'boundingbox': ['37.6757056', '37.6931455', '-121.8531778', '-121.8485356'],
#   'display_name': 'Shadow Cliffs, Pleasanton, Alameda County, California, 94568, USA',
#   'lat': '37.6796932698194',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.84980577536',
#   'osm_id': '93786215',
#   'osm_type': 'way',
#   'place_id': '96170855'},
#  '982': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '3249',
#    'neighbourhood': 'Shadow Cliffs',
#    'postcode': '94566',
#    'road': 'Sylvaner Court',
#    'state': 'California',
#    'town': 'Pleasanton'},
#   'boundingbox': ['37.659885183673',
#    '37.660085183674',
#    '-121.85006922449',
#    '-121.84986922449'],
#   'display_name': '3249, Sylvaner Court, Shadow Cliffs, Pleasanton, Alameda County, California, 94566, USA',
#   'lat': '37.6599851836735',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.84996922449',
#   'osm_id': '6340815',
#   'osm_type': 'way',
#   'place_id': '204083408'},
#  '983': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '573',
#    'neighbourhood': 'Shadow Cliffs',
#    'postcode': '94566',
#    'road': 'Rowell Lane',
#    'state': 'California',
#    'town': 'Pleasanton'},
#   'boundingbox': ['37.659791', '37.659991', '-121.859697', '-121.859497'],
#   'display_name': '573, Rowell Lane, Shadow Cliffs, Pleasanton, Alameda County, California, 94566, USA',
#   'lat': '37.659891',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.859597',
#   'osm_id': '6348331',
#   'osm_type': 'way',
#   'place_id': '204135502'},
#  '984': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '485',
#    'postcode': '94566',
#    'road': 'Pine Hill Lane',
#    'state': 'California',
#    'town': 'Pleasanton'},
#   'boundingbox': ['37.659957948387',
#    '37.660157948387',
#    '-121.87012087096',
#    '-121.86992087096'],
#   'display_name': '485, Pine Hill Lane, Pleasanton, Alameda County, California, 94566, USA',
#   'lat': '37.6600579483868',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.870020870959',
#   'osm_id': '6368111',
#   'osm_type': 'way',
#   'place_id': '204100011'},
#  '985': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'neighbourhood': 'Shadow Cliffs',
#    'postcode': '94566',
#    'road': 'Foxborough Place',
#    'state': 'California',
#    'town': 'Pleasanton'},
#   'boundingbox': ['37.6603243', '37.6605093', '-121.8412737', '-121.8405072'],
#   'display_name': 'Foxborough Place, Shadow Cliffs, Pleasanton, Alameda County, California, 94566, USA',
#   'lat': '37.6605093',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.8405072',
#   'osm_id': '628570783',
#   'osm_type': 'way',
#   'place_id': '240096725'},
#  '986': {'address': {'city': 'Dublin',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '5165',
#    'postcode': '94568',
#    'road': 'Salerno Drive',
#    'state': 'California'},
#   'boundingbox': ['37.7199088', '37.7201088', '-121.8500788', '-121.8498788'],
#   'display_name': '5165, Salerno Drive, Dublin, Alameda County, California, 94568, USA',
#   'lat': '37.7200088',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.8499788',
#   'osm_id': '4933597791',
#   'osm_type': 'node',
#   'place_id': '61312082'},
#  '987': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'state': 'California'},
#   'boundingbox': ['37.4539501', '37.9066896', '-122.3737488', '-121.4690903'],
#   'display_name': 'Alameda County, California, USA',
#   'lat': '37.6090291',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.899142',
#   'osm_id': '396499',
#   'osm_type': 'relation',
#   'place_id': '198061856'},
#  '988': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '3121',
#    'postcode': '94588',
#    'road': 'Kirkcaldy Street',
#    'state': 'California',
#    'town': 'Pleasanton'},
#   'boundingbox': ['37.699910137597',
#    '37.700110137597',
#    '-121.86010015455',
#    '-121.85990015455'],
#   'display_name': '3121, Kirkcaldy Street, Pleasanton, Alameda County, California, 94588, USA',
#   'lat': '37.700010137597',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.86000015455',
#   'osm_id': '6382811',
#   'osm_type': 'way',
#   'place_id': '204133967'},
#  '989': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'postcode': '94566',
#    'road': 'Gibraltar Drive South',
#    'state': 'California',
#    'town': 'Pleasanton'},
#   'boundingbox': ['37.6872503', '37.6912638', '-121.8936543', '-121.8903841'],
#   'display_name': 'Gibraltar Drive South, Pleasanton, Alameda County, California, 94566, USA',
#   'lat': '37.6898429000944',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.89046245495',
#   'osm_id': '6356777',
#   'osm_type': 'way',
#   'place_id': '70341640'},
#  '990': {'address': {'city': 'Livermore',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '2999',
#    'postcode': '94550',
#    'road': 'Lerida Court',
#    'state': 'California'},
#   'boundingbox': ['37.649196', '37.649396', '-121.770719', '-121.770519'],
#   'display_name': '2999, Lerida Court, Livermore, Alameda County, California, 94550, USA',
#   'lat': '37.649296',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.770619',
#   'osm_id': '24300733',
#   'osm_type': 'way',
#   'place_id': '204057069'},
#  '991': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'hamlet': 'Mendenhall Springs',
#    'state': 'California'},
#   'boundingbox': ['37.5482655', '37.6282655', '-121.6877267', '-121.6077267'],
#   'display_name': 'Mendenhall Springs, Alameda County, California, USA',
#   'lat': '37.5882655',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.6477267',
#   'osm_id': '150939058',
#   'osm_type': 'node',
#   'place_id': '347475'},
#  '992': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'state': 'California'},
#   'boundingbox': ['37.4539501', '37.9066896', '-122.3737488', '-121.4690903'],
#   'display_name': 'Alameda County, California, USA',
#   'lat': '37.6090291',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.899142',
#   'osm_id': '396499',
#   'osm_type': 'relation',
#   'place_id': '198061856'},
#  '993': {'address': {'city': 'Livermore',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '5800',
#    'neighbourhood': 'Sunrise Mobile Home Park',
#    'postcode': '94550',
#    'road': 'Brisa Street',
#    'state': 'California'},
#   'boundingbox': ['37.699116', '37.699316', '-121.720067', '-121.719867'],
#   'display_name': '5800, Brisa Street, Sunrise Mobile Home Park, Livermore, Alameda County, California, 94550, USA',
#   'lat': '37.699216',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.719967',
#   'osm_id': '93996077',
#   'osm_type': 'way',
#   'place_id': '204102829'},
#  '994': {'address': {'city': 'Livermore',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '5301',
#    'neighbourhood': 'Villa Chardonnay',
#    'postcode': '94551',
#    'road': 'Hillflower Drive',
#    'state': 'California'},
#   'boundingbox': ['37.709861', '37.710061', '-121.730679', '-121.730479'],
#   'display_name': '5301, Hillflower Drive, Villa Chardonnay, Livermore, Alameda County, California, 94551, USA',
#   'lat': '37.709961',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.730579',
#   'osm_id': '6377453',
#   'osm_type': 'way',
#   'place_id': '204118579'},
#  '995': {'address': {'city': 'Livermore',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '4190',
#    'neighbourhood': 'Spring Valley',
#    'postcode': '94551',
#    'road': 'Redwood Road',
#    'state': 'California'},
#   'boundingbox': ['37.709672', '37.709872', '-121.749843', '-121.749643'],
#   'display_name': '4190, Redwood Road, Spring Valley, Livermore, Alameda County, California, 94551, USA',
#   'lat': '37.709772',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.749743',
#   'osm_id': '6331541',
#   'osm_type': 'way',
#   'place_id': '204062239'},
#  '996': {'address': {'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '5822',
#    'neighbourhood': 'The Reserve',
#    'postcode': '94551',
#    'road': 'North Livermore Avenue',
#    'state': 'California'},
#   'boundingbox': ['37.73990378868',
#    '37.74010378868',
#    '-121.77012845872',
#    '-121.76992845872'],
#   'display_name': '5822, North Livermore Avenue, The Reserve, Alameda County, California, 94551, USA',
#   'lat': '37.7400037886799',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.770028458717',
#   'osm_id': '6328290',
#   'osm_type': 'way',
#   'place_id': '204144323'},
#  '997': {'address': {'city': 'Livermore',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'postcode': '94551',
#    'road': 'Arthur H. Breed Junior Freeway',
#    'state': 'California'},
#   'boundingbox': ['37.7007028', '37.7007742', '-121.8090937', '-121.7999021'],
#   'display_name': 'Arthur H. Breed Junior Freeway, Livermore, Alameda County, California, 94551, USA',
#   'lat': '37.7007042025504',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.799988578961',
#   'osm_id': '47220143',
#   'osm_type': 'way',
#   'place_id': '88218063'},
#  '998': {'address': {'city': 'Livermore',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'house_number': '198',
#    'postcode': '94551',
#    'road': 'Wright Brothers Avenue',
#    'state': 'California'},
#   'boundingbox': ['37.689780035065',
#    '37.689980035065',
#    '-121.80011001068',
#    '-121.79991001068'],
#   'display_name': '198, Wright Brothers Avenue, Livermore, Alameda County, California, 94551, USA',
#   'lat': '37.6898800350646',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.80001001068',
#   'osm_id': '24298728',
#   'osm_type': 'way',
#   'place_id': '204104632'},
#  '999': {'address': {'aerodrome': 'Livermore Municipal Airport',
#    'city': 'Livermore',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'Alameda County',
#    'postcode': '94568',
#    'road': 'Terminal Circle',
#    'state': 'California'},
#   'boundingbox': ['37.6896004', '37.6972123', '-121.8319159', '-121.8058167'],
#   'display_name': 'Livermore Municipal Airport, Terminal Circle, Livermore, Alameda County, California, 94568, USA',
#   'lat': '37.6934357',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'lon': '-121.818725979771',
#   'osm_id': '611877711',
#   'osm_type': 'way',
#   'place_id': '197988941'},
#  ...}

# %%
df_geo = pd.DataFrame(
    [(r['address'].get('postcode'), r['address']['county']) for r in results.values()],
    columns=['zip_code', 'county'],
    index=[int(k) for k in results.keys()]
)

# %%
df_geo.isnull().sum()
# Out:
# zip_code    877
# county        0
# dtype: int64

# %%
df = df.merge(df_geo, left_index=True, right_index=True)
df.shape
# Out:
# (20374, 11)

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  median_house_value zip_code               county
# 0    -122.23               4.526    94611  Contra Costa County
# 1    -122.22               3.585    94611       Alameda County
# 2    -122.24               3.521    94618       Alameda County
# 3    -122.25               3.413    94618       Alameda County
# 4    -122.25               3.422    94618       Alameda County

# %% [markdown]
# # Add text data from wikipedia

# %%
import string
import re
import requests as rq
import bs4

endpoint = 'https://en.wikipedia.org/w/api.php'

search_params = {
    'action': 'query',
    'list': 'search',
    'format': 'json',
    'srsearch': None
}

page_params = {
    'action': 'parse',
    'format': 'json',
    'prop': 'text',
    'pageid': None
}


def query_wiki(query):
    response_json = _search_wiki(query)
    page_id = _extract_pageid(response_json)
    page_xml = _fetch_page_content(page_id)
    article = _parse_xml(page_xml)
    return _clean_article(article)

def _search_wiki(query):
    params = search_params.copy()
    params.update({'srsearch': query})
    response = rq.get(endpoint, params=params)
    return response

def _extract_pageid(response):
    json = response.json()
    # just take first result
    pageid = json[u'query'][u'search'][0][u'pageid']
    return pageid

def _fetch_page_content(pageid):
    params = page_params.copy()
    params.update({'pageid': str(pageid)})
    json = rq.get(endpoint, params=params).json()
    content = json[u'parse'][u'text'][u'*']
    return content

def _parse_xml(page_xml):
    soup = bs4.BeautifulSoup(page_xml, 'lxml')
    _ = [s.extract() for s in soup(['script', '[document]', 'head', 'title'])]
    return soup.getText()

def _clean_word(word):
    # remove references
    word = re.sub('\[[0-9]*\]', '', word)
    # remove punctuation
    word = word.translate({s: None for s in string.punctuation})
    return word

def _clean_article(article):
    def take_line(L):
        take = (
            # take text if it looks like a paragraph or full sentence
            (L.count('.') > 2 or L.count(' ') > 12) 
            # remove references at bottome of artcile
            and not L.startswith('^') 
            # Remove article meta-comments
            and not L.startswith('‹')
            and not ('•' in L)
            and not L.startswith('Images, from')
            and not L.startswith(u'This article needs to be updated') 
            and not L.endswith(u'(Learn how and when to remove this template message)') 
            and not L.startswith(u'This article is about') 
            and not L.endswith(u'This article has multiple issues') 
            and not re.match('^For the[^\.].*, see.*\.$', L) 
            and not re.match('".*" redirects here.', L))
        return take
    text = '\n'.join(L for L in article.split('\n') if take_line(L))
    text = ' '.join(_clean_word(word) for word in text.split())
    return ' '.join(text.split())

# %%
counties = df.county.unique()
counties
# Out:
# array(['Contra Costa County', 'Alameda County', 'Alpine County',
#        'Amador County', 'Butte County', 'Calaveras County',
#        'Colusa County', 'Marin County', 'Del Norte County',
#        'Douglas County', 'El Dorado County', 'Fresno County',
#        'Tulare County', 'Glenn County', 'Humboldt County',
#        'Imperial County', 'Inyo County', 'Kern County', 'Kings County',
#        'Lake County', 'Lassen County', 'Los Angeles County',
#        'San Bernardino County', 'Orange County', 'Ventura County',
#        'Madera County', 'Mariposa County', 'Mendocino County',
#        'Merced County', 'Modoc County', 'Mono County', 'Monterey County',
#        'Napa County', 'Nevada County', 'San Diego County',
#        'Placer County', 'Sacramento County', 'Plumas County',
#        'Riverside County', 'La Paz County', 'San Benito County',
#        'Municipio de Tijuana', 'SF', 'San Joaquin County',
#        'San Luis Obispo County', 'San Mateo County', 'Santa Clara County',
#        'Santa Barbara County', 'Santa Cruz County', 'Shasta County',
#        'Sierra County', 'Siskiyou County', 'Solano County',
#        'Sonoma County', 'Stanislaus County', 'Sutter County',
#        'Tehama County', 'Trinity County', 'Tuolumne County',
#        'Yolo County', 'Yuba County'], dtype=object)

# %%
county_descriptions = {c: query_wiki(c) for c in counties}

# %%
df['county_description'] = df.county.map(county_descriptions)

# %%
df[['county', 'county_description']].drop_duplicates().head()
# Out:
#                    county                                 county_description
# 0     Contra Costa County  Contra Costa County is a county in the state o...
# 1          Alameda County  Alameda County (/ˌæləˈmiːdə/ AL-ə-MEE-də) is a...
# 1022        Alpine County  Alpine County is a county in the U.S. state of...
# 1025        Amador County  Amador County, is a county in the U.S. state o...
# 1053         Butte County  Butte County is a county in the U.S. state of ...

# %% [markdown]
# # Create train/test split

# %%
import numpy as np
df['is_train'] = np.random.choice([True, False], p=[0.8, 0.2], size=len(df))

# %% [markdown]
# # Encode categorical values

# %%
# roughly clean zip codes first
import numpy as np
zip_codes_raw = (df.zip_code
 .str.replace('CA ', '')
 .str.split('-', n=0, expand=True))[0]
zip_codes_raw.fillna(0, inplace=True)
zip_codes_raw = np.where(zip_codes_raw.str.isdigit(), zip_codes_raw, 0)
df['zip_code'] = zip_codes_raw.astype(int)

# %%
zip_code_encodings = {v: i for i, v in enumerate(df[df.is_train].zip_code.unique())}
county_encodings = {v: i for i, v in enumerate(df[df.is_train].county.unique())}
len(zip_code_encodings), len(county_encodings)
# Out:
# (1650, 61)

# %%
df['zip_code_encoding'] = df.zip_code.map(zip_code_encodings)
df['county_encoding'] = df.county.map(county_encodings)

# %%
# add "unkown" encodings
# df['zip_code_encoding'] = 
df.zip_code_encoding.fillna(len(zip_code_encodings), inplace=True)
df.county_encoding.fillna(len(county_encodings), inplace=True)

# %%
df['zip_code_encoding'] = df.zip_code_encoding.astype(int)
df['county_encoding'] = df.county_encoding.astype(int)

# %% [markdown]
# # dump data frame to disk

# %%
df.to_csv('california_housing_enriched.csv.gz', index=False, compression='gzip')
